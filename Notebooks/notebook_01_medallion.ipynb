# %% [markdown]
# #Medallion architecture
#
# ### Let's create the databases for each layer of the Medallion architecture:
#
# ## **Bronze** -> **Silver** -> **Gold** -> **Analytics**.
#
# ### Where:
#
# ### **Bronze**: Raw data
# ### **Silver**: Clean data
# ### **Gold**: Modeled data
# ### **Analytics**: Final consumption

# %%
# %sql
 -- Create a database for the Bronze layer
 CREATE DATABASE IF NOT EXISTS bronze; 

 -- Create a database for the Silver layer  
 CREATE DATABASE IF NOT EXISTS silver; 

 -- Create a database for the Gold layer  
 CREATE DATABASE IF NOT EXISTS gold;

 -- Create a database for the Analytics layer 
 CREATE DATABASE IF NOT EXISTS analytics
