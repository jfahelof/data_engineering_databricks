# %% [markdown]
# # Arquitetura Medallion
#
# ### Vamos criar os banco de dados (schemas) para cada camada da estrutura medallion:
#
# ## **Bronze** -> **Silver** -> **Gold** -> **Analytics**.
#
# ### Onde:
#
# ### **Bronze**: ingestão de dados brutos.
# ### **Silver**: limpeza, tratamento e padronização.
# ### **Gold**: tabelas analíticas e métricas.

# %%
# %sql
 -- Cria um banco de dados para a camada Bronze
 CREATE DATABASE IF NOT EXISTS bronze; 

 -- Cria um banco de dados para a camada Silver
 CREATE DATABASE IF NOT EXISTS silver; 

 -- Cria um banco de dados para a camada Gold
 CREATE DATABASE IF NOT EXISTS gold;
